# %%
# !python train_interpreter-Sspace.py --exp experiments/datasetgan_cloth_620t.json
# Out:
# 00000000000cuda_home: /usr/local/cuda-11.1
# Opt {'exp_dir': '../editGANresult/model_interpreter/cloth_620t_6-class', 'batch_size': 64, 'category': 'car', 'debug': False, 'dim': [256, 256, 4992], 'number_class': 3, 'testing_data_number_class': 3, 'max_training': 15, 'stylegan_ver': '3', 'annotation_data_from_w': True, 'annotation_mask_path': '../editGANdata/train_data_for_620t_classifier_6-class/cloth_620t_6-class_mask_latents', 'testing_path': '', 'stylegan_checkpoint': 'cloth-v2-620t-s-test.pkl', 'model_num': 10, 'upsample_mode': 'bilinear', 'optimized_latent_path': {'train': '../editGANdata/train_data_for_620t_classifier_6-class/cloth_620t_6-class_images_s', 'test': ''}}
# main start
# Loading networks from "cloth-v2-620t-s-test.pkl"...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
#  make_mean_latent
# next step: initialize all_feature_maps_train and all_mask_train
# all_feature_maps_train.shape (983040, 4992)
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# ...

# %%
# !python make_seg.py
# Out:
# 00000000000cuda_home: /usr/local/cuda-11.1
# Setting up PyTorch plugin "bias_act_plugin"... Done.
#  make_mean_latent
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Loading networks from "cloth-v2-620t-s-test.pkl"...
#  make_mean_latent
# Load Classifier path,  ../editGANresult/model_interpreter/cloth_620t_6-class
# TOOL init!!

# %%
# !python train_interpreter-Sspace.py --exp experiments/datasetgan_cloth_360t.json
# Out:
# 00000000000cuda_home: /usr/local/cuda-11.1
# Opt {'exp_dir': '../editGANresult/model_interpreter/cloth_360t_6-class', 'batch_size': 64, 'category': 'car', 'debug': False, 'dim': [256, 256, 4992], 'number_class': 6, 'testing_data_number_class': 6, 'max_training': 15, 'stylegan_ver': '3', 'annotation_data_from_w': True, 'annotation_mask_path': '../editGANdata/train_data_for_360t_classifier_6-class/cloth_360t_6-class_mask_latents', 'testing_path': '', 'stylegan_checkpoint': 'viton_360t_s_fm.pkl', 'model_num': 10, 'upsample_mode': 'bilinear', 'optimized_latent_path': {'train': '../editGANdata/train_data_for_360t_classifier_6-class/cloth_360t_6-class_images_s', 'test': ''}}
# Experiment folder created at: ../editGANresult/model_interpreter/cloth_360t_6-class
# main start
# Loading networks from "viton_360t_s_fm.pkl"...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
#  make_mean_latent
# next step: initialize all_feature_maps_train and all_mask_train
# ...
