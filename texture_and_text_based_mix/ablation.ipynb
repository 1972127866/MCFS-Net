# %%
# all_s_extra_mapper 删除了img_loss
# collar
# !python scripts/flexible_inference_texture_all_s_extra_mapper_img_loss.py \
           -save_name collar_deepfashion_wo_img_loss \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -stylegan_weights /home/scut/workspace/wanqing/editGAN/collar_cloth_8385_300t.pt \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s_extra_mapper/collar_cloth_8385_300t_sample_200000_all_s/texture_cropped_sample_200000_collar_cloth_8385_300t/net_1920000.pth \
           -save_path output/ablation \
           -sample_w_path /home/scut/workspace/wanqing/editGANdata/collar_cloth_8385_300t_sample_200000/w
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  9.10it/s]
# Loading all textures in folder
# 100%|████████████████████████████████████████| 400/400 [00:02<00:00, 196.12it/s]
# len(delta_c_list): 300
# generating result
# 300it [00:03, 94.64it/s]
# completed👍! Please check results in output/ablation/collar_deepfashion_wo_img_loss

# %%
# all_s_extra_mapper 删除了img_loss
# 620t
# !python scripts/flexible_inference_texture_all_s_extra_mapper_img_loss.py \
           -save_name 620t_deepfashion_wo_img_loss \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s_extra_mapper/resume/620t_sample_200000_all_s/texture_cropped_sample_200000_620t/net_1280000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  9.29it/s]
# Loading all textures in folder
# 100%|████████████████████████████████████████| 400/400 [00:01<00:00, 203.68it/s]
# len(delta_c_list): 300
# generating result
# 300it [00:03, 94.28it/s]
# completed👍! Please check results in output/ablation/620t_deepfashion_wo_img_loss

# %%
# all_s_img_loss 删除了extra mapper
# collar
# !python scripts/flexible_inference_texture_all_s_img_loss.py \
           -save_name collar_deepfashion_wo_extra_mapper \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -stylegan_weights /home/scut/workspace/wanqing/editGAN/collar_cloth_8385_300t.pt \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s_img_loss/collar_cloth_8385_300t_sample_200000_all_s/texture_cropped_sample_200000_collar_cloth_8385_300t/net_1920000.pth \
           -save_path output/ablation \
           -sample_w_path /home/scut/workspace/wanqing/editGANdata/collar_cloth_8385_300t_sample_200000/w
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 10.13it/s]
# Loading all textures in folder
# 100%|████████████████████████████████████████| 400/400 [00:01<00:00, 200.62it/s]
# len(delta_c_list): 300
# generating result
# 300it [00:03, 94.06it/s]
# completed👍! Please check results in output/ablation/collar_deepfashion_wo_extra_mapper

# %%
# all_s_img_loss 删除了extra mapper
# 620t
# !python scripts/flexible_inference_texture_all_s_img_loss.py \
           -save_name 620t_deepfashion_wo_extra_mapper \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s_img_loss/620t_sample_200000_all_s/texture_cropped_sample_200000_620t/net_1920000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  9.31it/s]
# Loading all textures in folder
# 100%|████████████████████████████████████████| 400/400 [00:01<00:00, 202.55it/s]
# len(delta_c_list): 300
# generating result
# 300it [00:03, 95.71it/s]
# completed👍! Please check results in output/ablation/620t_deepfashion_wo_extra_mapper

# %%
# orig model
# collar
# !python scripts/flexible_inference_texture.py \
           -save_name collar_deepfashion_orig_model \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -stylegan_weights /home/scut/workspace/wanqing/editGAN/collar_cloth_8385_300t.pt \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/orig_model/collar_cloth_8385_300t_sample_200000/texture_cropped_sample_200000_collar_cloth_8385_300t/net_1920000.pth \
           -save_path output/ablation \
           -sample_w_path /home/scut/workspace/wanqing/editGANdata/collar_cloth_8385_300t_sample_200000/w
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  5.40it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:07<00:00, 53.96it/s]
# len(delta_c_list): 300
# generating result
# 0it [00:00, ?it/s]111
# 222
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 256, 1, 1])
# torch.Size([1, 1, 128, 1, 1])
# torch.Size([1, 1, 64, 1, 1])
# 333
# 111
# 222
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 256, 1, 1])
# torch.Size([1, 1, 128, 1, 1])
# torch.Size([1, 1, 64, 1, 1])
# 333
# 111
# 222
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 512, 1, 1])
# torch.Size([1, 1, 256, 1, 1])
# ...

# %%
# orig model
# 620t
# !python scripts/flexible_inference_texture.py \
           -save_name 620t_deepfashion_orig_model \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/orig_model/620t_sample_200000/texture_cropped_sample_200000_620t/net_1920000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  5.30it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:07<00:00, 54.09it/s]
# len(delta_c_list): 300
# generating result
# 300it [00:12, 24.20it/s]
# completed👍! Please check results in output/ablation/620t_deepfashion_orig_model

# %%
# all s (没有extra mapper，texture loss)
# 620t
# !python scripts/flexible_inference_texture_all_s.py \
           -save_name 620t_deepfashion_all_s \
           -cloth_ids 0-2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s/620t_sample_200000_all_s/texture_cropped_sample_200000_620t/net_1920000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.32it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:07<00:00, 52.39it/s]
# len(delta_c_list): 150
# generating result
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/flexible_inference_texture_all_s.py", line 214, in <module>
#     main(opt)
#   File "scripts/flexible_inference_texture_all_s.py", line 145, in main
#     fake_delta_s = net(latent_s, delta_c)
#   File "/home/scut/workspace/anaconda3/envs/deltaEdit/lib/python3.8/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "./delta_mapper_all_s.py", line 76, in forward
#     x_fine   = self.fm_fine(x_fine)
#   File "/home/scut/workspace/anaconda3/envs/deltaEdit/lib/python3.8/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
# ...

# %%
# all s (没有extra mapper，texture loss)
# collar
# !python scripts/flexible_inference_texture_all_s.py \
           -save_name collar_deepfashion_all_s_0_2 \
           -cloth_ids 2  \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -stylegan_weights /home/scut/workspace/wanqing/editGAN/collar_cloth_8385_300t.pt \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s/collar_cloth_8385_300t_sample_200000_all_s/texture_cropped_sample_200000_collar_cloth_8385_300t/net_1920000.pth \
           -save_path output/ablation \
           -sample_w_path /home/scut/workspace/wanqing/editGANdata/collar_cloth_8385_300t_sample_200000/w
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:05<00:00, 77.93it/s]
# len(delta_c_list): 100
# generating result
# 100it [00:09, 10.98it/s]
# completed👍! Please check results in output/ablation/collar_deepfashion_all_s_0_2
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 16.06it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:04<00:00, 83.86it/s]
# len(delta_c_list): 100
# generating result
# 100it [00:09, 10.98it/s]
# completed👍! Please check results in output/ablation/collar_deepfashion_all_s_0_2
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 16.40it/s]
# ...

# %%
# all s (没有extra mapper，texture loss)
# 生成实验结果图
# !python scripts/flexible_inference_texture_all_s.py \
           -save_name all_s_deep_fashion_cids_1 \
           -cloth_ids 1 \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s/620t_sample_200000_all_s/texture_cropped_sample_200000_620t/net_1920000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.41it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:05<00:00, 78.25it/s]
# len(delta_c_list): 100
# generating result
# 100it [00:08, 11.24it/s]
# completed👍! Please check results in output/ablation/all_s_deep_fashion_cids_1

# %%
# all s (没有extra mapper，texture loss)
# 生成实验结果图
# !python scripts/flexible_inference_texture_all_s.py \
           -save_name all_s_deep_fashion_cids_0_2 \
           -cloth_ids 2 \
           -texture_path /home/scut/workspace/wanqing/editGANdata/deep_fashion_multi_model_texture_400 \
           -checkpoint_path /home/scut/workspace/wanqing/DeltaEdit-main/checkpoints/all_s/620t_sample_200000_all_s/texture_cropped_sample_200000_620t/net_1920000.pth \
           -save_path output/ablation
# Out:
# Loading stylegan weights from pretrained!
# sampling cloths
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.34it/s]
# Loading all textures in folder
# 100%|█████████████████████████████████████████| 400/400 [00:05<00:00, 77.93it/s]
# len(delta_c_list): 100
# generating result
# 100it [00:09, 10.91it/s]
# completed👍! Please check results in output/ablation/all_s_deep_fashion_cids_0_2
